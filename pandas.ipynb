# %%
import numpy as np
import pandas as pd
from numpy.random import randn

np.random.seed(100)   #.........produces the same random numbers...........

# %%
Labels = ['a','b', 'c']
my_data = [10,20,30]
arr = np.array(my_data)
d = {'a':10, 'b':20, 'c':30}

# %%
pd.Series(arr,Labels)

#............The all will print the same data in same formate.................

#pd.Series(data = my_data, index = Labels)
#pd.Series(data = my_data, labels)
#pd.Series(my_data)
#pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
series1 = pd.Series([1,2,3,4,5],['Pakistan','India','China','Afghanistan','Nepal'])
series1
# Out:
# Pakistan       1
# India          2
# China          3
# Afghanistan    4
# Nepal          5
# dtype: int64

# %%
series2 = pd.Series([2,4,5],['Pakistan','Bangladesh','Nepal'])
series2
# Out:
# Pakistan      2
# Bangladesh    4
# Nepal         5
# dtype: int64

# %%
series1 + series2
# Out:
# Afghanistan     NaN
# Bangladesh      NaN
# China           NaN
# India           NaN
# Nepal          10.0
# Pakistan        3.0
# dtype: float64

# %%
df = pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])
df
# Out:
#           W         X         Y         Z
# A -1.749765  0.342680  1.153036 -0.252436
# B  0.981321  0.514219  0.221180 -1.070043
# C -0.189496  0.255001 -0.458027  0.435163
# D -0.583595  0.816847  0.672721 -0.104411
# E -0.531280  1.029733 -0.438136 -1.118318

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A -1.749765  0.342680  1.153036 -0.252436 -0.596730
# B  0.981321  0.514219  0.221180 -1.070043  1.202500
# C -0.189496  0.255001 -0.458027  0.435163 -0.647523
# D -0.583595  0.816847  0.672721 -0.104411  0.089126
# E -0.531280  1.029733 -0.438136 -1.118318 -0.969416

# %%
df.drop('new', axis = 1)
# Out:
#           W         X         Y         Z
# A -1.749765  0.342680  1.153036 -0.252436
# B  0.981321  0.514219  0.221180 -1.070043
# C -0.189496  0.255001 -0.458027  0.435163
# D -0.583595  0.816847  0.672721 -0.104411
# E -0.531280  1.029733 -0.438136 -1.118318

# %%
df
# Out:
#           W         X         Y         Z       new
# A -1.749765  0.342680  1.153036 -0.252436 -0.596730
# B  0.981321  0.514219  0.221180 -1.070043  1.202500
# C -0.189496  0.255001 -0.458027  0.435163 -0.647523
# D -0.583595  0.816847  0.672721 -0.104411  0.089126
# E -0.531280  1.029733 -0.438136 -1.118318 -0.969416

# %%
df.drop('new', axis=1, inplace=True)

# %%
df > 1
# Out:
#        W      X      Y      Z
# A  False  False   True  False
# B  False  False  False  False
# C  False  False  False  False
# D  False  False  False  False
# E  False   True  False  False

# %%
booldf = df >0 #............It creates a boolean DataFrame...............

# %%
booldf
# Out:
#        W     X      Y      Z
# A  False  True   True  False
# B   True  True   True  False
# C  False  True  False   True
# D  False  True   True  False
# E  False  True  False  False

# %%
df[booldf]  #......It Shows values only where it is greater than (df > 0) zero and NaN where df <= 0...........
# Out:
#           W         X         Y         Z
# A       NaN  0.342680  1.153036       NaN
# B  0.981321  0.514219  0.221180       NaN
# C       NaN  0.255001       NaN  0.435163
# D       NaN  0.816847  0.672721       NaN
# E       NaN  1.029733       NaN       NaN

# %%
df[df['W'] > 0]
# Out:
#           W         X        Y         Z
# B  0.981321  0.514219  0.22118 -1.070043

# %%
pwd
# Out:
# 'C:\\Users\\LOOSER\\Desktop\\Python Programmes'

# %%
pd = pd.read_csv('Births.csv')

# %%
pd
# Out:
#              geography type    code                 description  2013  2014  \
# 0     Statistical_Area_2_18  100100                  North Cape    12    15
# 1     Statistical_Area_2_19  100200            Rangaunu Harbour    39    33
# 2     Statistical_Area_2_20  100300   Inlets Far North District     0     0
# 3     Statistical_Area_2_21  100400          Karikari Peninsula    12    15
# 4     Statistical_Area_2_22  100500                    Tangonge    18     3
# 5     Statistical_Area_2_23  100600                     Ahipara     9    12
# 6     Statistical_Area_2_24  100700                Kaitaia East    51    45
# 7     Statistical_Area_2_25  100800                Kaitaia West    48    63
# 8     Statistical_Area_2_26  100900                   Rangitihi     6    12
# 9     Statistical_Area_2_27  101000              Oruru-Parapara    12    15
# 10    Statistical_Area_2_28  101100                 Taumarumaru    27    24
# ...

# %%
pd.columns
# Out:
# Index(['geography type', 'code', 'description', '2013', '2014', '2015', '2016',
#        '2017'],
#       dtype='object')

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')
